# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
##Extract CSVs into DataFrames

# %%
Merge_Hotels_file = (r"c:/Users/George Aziz/desktop/ETL-Project/airbb_data/airbb_merge.csv")
Merge_Hotels_df = pd.read_csv(Merge_Hotels_file)
Merge_Hotels_df.head()
# Out:
#       id                         listing_url  \
# 0   6623   https://www.airbnb.com/rooms/6623
# 1   6624   https://www.airbnb.com/rooms/6624
# 2  12074  https://www.airbnb.com/rooms/12074
# 3  21974  https://www.airbnb.com/rooms/21974
# 4  23197  https://www.airbnb.com/rooms/23197
#
#                                               name  \
# 0                   Venice Blue on Canal apartment
# 1             Venice garden charme and canal view!
# 2                Venice home to relax and emotions
# 3               Comf. double room/private bathroom
# 4  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
#
#                                          description  \
# 0  I'm thrilled to share my "Blue on Venice Canal...
# 1  I'm thrilled to share my apartment with garden...
# 2  I'm thrilled to share my home to guests coming...
# 3  It is private double room with private bathroo...
# 4  Beautiful apartment, large terrace, 5 minutes ...
#
# ...

# %%
### Transform CSV file one Merge Hotels

# %%
list(Merge_Hotels_df)
# Out:
# ['id',
#  'listing_url',
#  'name',
#  'description',
#  'picture_url',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'beds',
#  'amenities',
#  'price',
#  'has_availability',
#  'review_scores_accuracy',
#  'review_scores_value',
#  'instant_bookable',
#  'reviews_per_month']

# %%
# select the columns
Merge_Hotels_df = Merge_Hotels_df[['id',
 'listing_url',
 'name',
 'description',
 'picture_url',
 'neighbourhood_cleansed',
 'neighbourhood_group_cleansed',
 'latitude',
 'longitude',
 'property_type',
 'room_type',
 'beds',
 'amenities',
 'price',
 'has_availability',
 'review_scores_accuracy',
 'review_scores_value',
 'instant_bookable',
 'reviews_per_month']]
# display the new dataframe
Merge_Hotels_df.head()
# Out:
#       id                         listing_url  \
# 0   6623   https://www.airbnb.com/rooms/6623
# 1   6624   https://www.airbnb.com/rooms/6624
# 2  12074  https://www.airbnb.com/rooms/12074
# 3  21974  https://www.airbnb.com/rooms/21974
# 4  23197  https://www.airbnb.com/rooms/23197
#
#                                               name  \
# 0                   Venice Blue on Canal apartment
# 1             Venice garden charme and canal view!
# 2                Venice home to relax and emotions
# 3               Comf. double room/private bathroom
# 4  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
#
#                                          description  \
# 0  I'm thrilled to share my "Blue on Venice Canal...
# 1  I'm thrilled to share my apartment with garden...
# 2  I'm thrilled to share my home to guests coming...
# 3  It is private double room with private bathroo...
# 4  Beautiful apartment, large terrace, 5 minutes ...
#
# ...

# %%
Merge_Hotels_df.columns=['Hotel_id',
 'Hotel_url',
 'Hotel_name',
 'Room_description',
 'pic_url',
 'neighbourhood',
 'neighbourhood_association',
 'latitude',
 'longitude',
 'property',
 'room_type',
 'beds_count',
 'Room_amenities',
 'Room_price',
 'availability',
 'reviews_accuracy',
 'reviews_count',
 'instant_bookable',
 'reviews_per_month']

Merge_Hotels_df.head()
# Out:
#    Hotel_id                           Hotel_url  \
# 0      6623   https://www.airbnb.com/rooms/6623
# 1      6624   https://www.airbnb.com/rooms/6624
# 2     12074  https://www.airbnb.com/rooms/12074
# 3     21974  https://www.airbnb.com/rooms/21974
# 4     23197  https://www.airbnb.com/rooms/23197
#
#                                         Hotel_name  \
# 0                   Venice Blue on Canal apartment
# 1             Venice garden charme and canal view!
# 2                Venice home to relax and emotions
# 3               Comf. double room/private bathroom
# 4  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
#
#                                     Room_description  \
# 0  I'm thrilled to share my "Blue on Venice Canal...
# 1  I'm thrilled to share my apartment with garden...
# 2  I'm thrilled to share my home to guests coming...
# 3  It is private double room with private bathroo...
# 4  Beautiful apartment, large terrace, 5 minutes ...
#
# ...

# %%
# change NaN values to 0
Merge_Hotels_df.fillna(0, inplace=True)
Merge_Hotels_df.head()
# Out:
#    Hotel_id                           Hotel_url  \
# 0      6623   https://www.airbnb.com/rooms/6623
# 1      6624   https://www.airbnb.com/rooms/6624
# 2     12074  https://www.airbnb.com/rooms/12074
# 3     21974  https://www.airbnb.com/rooms/21974
# 4     23197  https://www.airbnb.com/rooms/23197
#
#                                         Hotel_name  \
# 0                   Venice Blue on Canal apartment
# 1             Venice garden charme and canal view!
# 2                Venice home to relax and emotions
# 3               Comf. double room/private bathroom
# 4  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★
#
#                                     Room_description  \
# 0  I'm thrilled to share my "Blue on Venice Canal...
# 1  I'm thrilled to share my apartment with garden...
# 2  I'm thrilled to share my home to guests coming...
# 3  It is private double room with private bathroo...
# 4  Beautiful apartment, large terrace, 5 minutes ...
#
# ...

# %%
print(Merge_Hotels_df.shape)
# Out:
# (19782, 19)

# %%
reviewed = Merge_Hotels_df[Merge_Hotels_df['reviews_count'] > 5]

# %%
reviewed['Room_price'] = reviewed['Room_price']
# Out:
# <ipython-input-59-cb580ec0e232>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviewed['Room_price'] = reviewed['Room_price']
