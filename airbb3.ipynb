# %%
import os
import pandas as pd
...
os.chdir(r'C:\Users\jonrs\Desktop\Bootcamp\80-group-projects\ETL-Project\airbb_data')

dfs = [pd.read_csv(f, index_col=[0])
        for f in os.listdir(os.getcwd()) if f.endswith('csv')]

finaldf = pd.concat(dfs, join='inner').sort_index()

# %%
list(finaldf)
# Out:
# ['listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'number_of_reviews_l30d',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'license',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
finaldf.drop(columns=['scrape_id',
 'last_scraped',
 'host_id',
 'host_url',
 'host_name',
 'host_since',
 'host_location',
 'host_about',
 'host_response_time',
 'host_response_rate',
 'host_thumbnail_url',
 'host_picture_url',
 'host_neighbourhood',
 'host_listings_count',
 'host_total_listings_count',
 'host_verifications',
 'host_has_profile_pic',
 'host_identity_verified',
 'bathrooms_text',
 'minimum_nights',
 'maximum_nights',
 'minimum_minimum_nights',
 'maximum_minimum_nights',
 'minimum_maximum_nights',
 'maximum_maximum_nights',
 'minimum_nights_avg_ntm',
 'maximum_nights_avg_ntm',
 'calendar_updated',
 'availability_30',
 'availability_60',
 'availability_90',
 'availability_365',
 'calendar_last_scraped',
 'number_of_reviews_ltm',
 'number_of_reviews_l30d',
 'first_review',
 'last_review',
 'license',
 'calculated_host_listings_count',
 'calculated_host_listings_count_entire_homes',
 'calculated_host_listings_count_private_rooms',
 'calculated_host_listings_count_shared_rooms',], inplace=True)

# %%
print(finaldf.shape)
# Out:
# (81311, 31)

# %%
finaldf
# Out:
#                                     listing_url  \
# id
# 6623          https://www.airbnb.com/rooms/6623
# 6624          https://www.airbnb.com/rooms/6624
# 11156        https://www.airbnb.com/rooms/11156
# 12074        https://www.airbnb.com/rooms/12074
# 12351        https://www.airbnb.com/rooms/12351
# ...                                         ...
# 47188002  https://www.airbnb.com/rooms/47188002
# 47194291  https://www.airbnb.com/rooms/47194291
# 47204945  https://www.airbnb.com/rooms/47204945
# 47208245  https://www.airbnb.com/rooms/47208245
# 47208934  https://www.airbnb.com/rooms/47208934
#
#                                                        name  \
# id
# 6623                         Venice Blue on Canal apartment
# 6624                   Venice garden charme and canal view!
# 11156                                  An Oasis in the City
# 12074                     Venice home to relax and emotions
# 12351                     Sydney City & Harbour at the door
# ...                                                     ...
# 47188002                       拉茶达华人区靠近网红夜市 特价促销中 月租13000泰铢
# 47194291   Boss House (NEAR MRT BL04)+4room+1bath+11people)
# 47204945  Luxury Room in the Bangkok City Near MRT Sukhu...
# 47208245     Cozy room Ratchada 17 near MRT Sutthisan 7 min
# 47208934                              Noble Ploenchit Condo
#
#                                                 description  \
# id
# 6623      I'm thrilled to share my "Blue on Venice Canal...
# 6624      I'm thrilled to share my apartment with garden...
# 11156     Very central to the city which can be reached ...
# 12074     I'm thrilled to share my home to guests coming...
# 12351     Come stay with Vinh & Stuart (Awarded as one o...
# ...                                                     ...
# 47188002  "独立的公寓，家具家电一应俱全，房东会中文／安静美丽的小区 在日暮降临后慢慢散步也是不错的选...
# 47194291  ที่พักย่านใจกลางเมืองราคาถูก เหมาะสำหรับคนต้อง...
# 47204945  Luxury Condominium in the Middle of Bangkok Ci...
# 47208245  Cozy Room 32 Sqm 3rd Floor with separate kitch...
# 47208934                                                NaN
#
#                                       neighborhood_overview  \
# id
# 6623      Close by is the Frari Church (known as Tiziano...
# 6624      We are in the middle of a residential area cal...
# 11156     It is very close to everything and everywhere,...
# 12074     There are plenty of bars, restaurants and pizz...
# 12351     Pyrmont is an inner-city village of Sydney, on...
# ...                                                     ...
# 47188002                                                NaN
# 47194291                                                NaN
# 47204945                                                NaN
# 47208245                                                NaN
# 47208934                                                NaN
#
#                                                 picture_url  \
# id
# 6623      https://a0.muscache.com/pictures/492258/834683...
# 6624      https://a0.muscache.com/pictures/65440024/a564...
# 11156     https://a0.muscache.com/pictures/2797669/17895...
# 12074     https://a0.muscache.com/pictures/11646330/65e7...
# 12351     https://a0.muscache.com/pictures/763ad5c8-c951...
# ...                                                     ...
# 47188002  https://a0.muscache.com/pictures/3d928095-38f4...
# 47194291  https://a0.muscache.com/pictures/368469f0-7595...
# 47204945  https://a0.muscache.com/pictures/e9bf946f-c127...
# 47208245  https://a0.muscache.com/pictures/a32eec40-8173...
# 47208934  https://a0.muscache.com/pictures/d46dcbc3-c580...
#
#          host_acceptance_rate host_is_superhost  \
# id
# 6623                      62%                 t
# 6624                      62%                 t
# 11156                    100%                 f
# 12074                     62%                 t
# 12351                     NaN                 f
# ...                       ...               ...
# 47188002                 100%                 f
# 47194291                 100%                 t
# 47204945                  NaN                 f
# 47208245                  NaN                 f
# 47208934                  NaN                 f
#
#                                     neighbourhood neighbourhood_cleansed  \
# id
# 6623                        Venice, Veneto, Italy               San Polo
# 6624                        Venice, Veneto, Italy            Santa Croce
# 11156     Potts Point, New South Wales, Australia                 Sydney
# 12074                       Venice, Veneto, Italy            Santa Croce
# 12351         Pyrmont, New South Wales, Australia                 Sydney
# ...                                           ...                    ...
# 47188002                                      NaN            Huai Khwang
# 47194291                                      NaN            Bangkok Noi
# 47204945                                      NaN                Vadhana
# 47208245                                      NaN              Din Daeng
# 47208934                                      NaN            Parthum Wan
#
#          neighbourhood_group_cleansed  ...  number_of_reviews  \
# id                                     ...
# 6623                            Isole  ...                162
# 6624                            Isole  ...                 64
# 11156                             NaN  ...                196
# 12074                           Isole  ...                184
# 12351                             NaN  ...                526
# ...                               ...  ...                ...
# 47188002                          NaN  ...                  0
# 47194291                          NaN  ...                  0
# 47204945                          NaN  ...                  0
# 47208245                          NaN  ...                  0
# 47208934                          NaN  ...                  0
#
#           review_scores_rating review_scores_accuracy  \
# id
# 6623                      99.0                   10.0
# 6624                     100.0                   10.0
# 11156                     92.0                   10.0
# 12074                     99.0                   10.0
# 12351                     95.0                   10.0
# ...                        ...                    ...
# 47188002                   NaN                    NaN
# 47194291                   NaN                    NaN
# 47204945                   NaN                    NaN
# 47208245                   NaN                    NaN
# 47208934                   NaN                    NaN
#
#          review_scores_cleanliness  review_scores_checkin  \
# id
# 6623                          10.0                   10.0
# 6624                          10.0                   10.0
# 11156                          9.0                   10.0
# 12074                         10.0                   10.0
# 12351                         10.0                   10.0
# ...                            ...                    ...
# 47188002                       NaN                    NaN
# 47194291                       NaN                    NaN
# 47204945                       NaN                    NaN
# 47208245                       NaN                    NaN
# 47208934                       NaN                    NaN
#
#           review_scores_communication  review_scores_location  \
# id
# 6623                             10.0                    10.0
# 6624                             10.0                    10.0
# 11156                            10.0                    10.0
# 12074                            10.0                    10.0
# 12351                            10.0                    10.0
# ...                               ...                     ...
# 47188002                          NaN                     NaN
# 47194291                          NaN                     NaN
# 47204945                          NaN                     NaN
# 47208245                          NaN                     NaN
# 47208934                          NaN                     NaN
#
#           review_scores_value instant_bookable reviews_per_month
# id
# 6623                     10.0                f              1.20
# 6624                     10.0                f              0.57
# 11156                    10.0                f              1.46
# 12074                    10.0                f              1.42
# 12351                    10.0                f              4.15
# ...                       ...              ...               ...
# 47188002                  NaN                t               NaN
# 47194291                  NaN                t               NaN
# 47204945                  NaN                f               NaN
# 47208245                  NaN                f               NaN
# 47208934                  NaN                f               NaN
#
# [81311 rows x 31 columns]

# %%
list(finaldf)
# Out:
# ['listing_url',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'has_availability',
#  'number_of_reviews',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'reviews_per_month']

# %%
finaldf.drop(columns=[
 'neighborhood_overview',
 'host_acceptance_rate',
 'host_is_superhost',
 'neighbourhood',
 'accommodates',
 'bathrooms',
 'bedrooms',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 ], inplace=True)

# %%
reviewed = finaldf[finaldf['number_of_reviews'] > 5]
reviewed['price'] = reviewed['price'].str.replace('$', '')
# Out:
# C:\Users\jonrs\anaconda3\envs\case_python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
reviewed['price'] = reviewed['price'].str.replace(',', '')
# Out:
# C:\Users\jonrs\anaconda3\envs\case_python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
reviewed['price'] = reviewed['price'].astype('float')
# Out:
# C:\Users\jonrs\anaconda3\envs\case_python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cheap = reviewed[reviewed['price'] < 100]
cheap_good = cheap[cheap['review_scores_rating'] > 95]
cheap_good.describe()
# Out:
#           latitude    longitude         beds        price  number_of_reviews  \
# count  5830.000000  5830.000000  5824.000000  5830.000000        5830.000000
# mean     16.577141    56.250758     1.595124    60.849302          69.947341
# std      36.603539    68.921713     1.083758    22.118625          86.191551
# min     -34.100160     2.089240     0.000000     8.000000           6.000000
# 25%     -33.832077     2.175587     1.000000    45.000000          13.000000
# 50%      41.385840    12.327140     1.000000    60.000000          35.000000
# 75%      45.430300   151.137047     2.000000    80.000000          91.000000
# max      45.537400   151.333690    16.000000    99.000000         773.000000
#
#        review_scores_rating  review_scores_accuracy  review_scores_value  \
# count           5830.000000             5820.000000          5820.000000
# mean              97.846655                9.961168             9.806014
# std                1.380383                0.194097             0.398051
# min               96.000000                8.000000             8.000000
# 25%               97.000000               10.000000            10.000000
# 50%               98.000000               10.000000            10.000000
# 75%               99.000000               10.000000            10.000000
# max              100.000000               10.000000            10.000000
#
#        reviews_per_month
# count        5830.000000
# mean            1.689681
# std             1.591418
# min             0.060000
# 25%             0.510000
# 50%             1.195000
# 75%             2.457500
# max            26.610000

# %%
covid = pd.read_csv('../time_series_covid_19_confirmed.csv')

# %%
from math import radians, cos, sin, asin, sqrt
def dist(lat1, long1, lat2, long2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lat1, long1, lat2, long2 = map(radians, [lat1, long1, lat2, long2])
    # haversine formula 
    dlon = long2 - long1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

# %%
def find_nearest(lat, long):
    distances = covid.apply(
        lambda row: dist(lat, long, row['Lat'], row['Long']), 
        axis=1)
    return covid.loc[distances.idxmin(), '1/19/2021']

# %%
cheap_good['covid'] = cheap_good.apply(
    lambda row: find_nearest(row['latitude'], row['longitude']), 
    axis=1)
# Out:
# C:\Users\jonrs\anaconda3\envs\case_python\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 35390   41.39153    2.15125          Private room in apartment
# 47383   45.43846   12.33235          Room in bed and breakfast
# 47549   45.43593   12.32521                   Entire apartment
# 49656   45.43549   12.32612                   Entire apartment
# 60304   45.44334   12.33483  Private room in bed and breakfast
# 61714   45.42708   12.31823  Private room in bed and breakfast
# 63267   45.43886   12.34990                   Entire apartment
# 67112  -33.91500  151.14030              Private room in house
# 68999  -33.72966  151.05226              Private room in house
# 69956  -33.93683  151.13528                 Entire guest suite
# 72436   41.39909    2.20733          Entire serviced apartment
# 72740   45.50700   12.28175                   Entire apartment
# 74042   45.43369   12.35051                   Entire apartment
# 77188   45.43385   12.34786                   Entire apartment
# 79624  -33.83096  151.21532              Private room in house
# 81631   41.40203    2.15752                   Entire apartment
# 87709  -33.70143  151.12514              Private room in house
# 89776   41.39149    2.17818                   Entire apartment
# 108271  45.47320   12.22502        Private room in condominium
# 119546  41.37969    2.16532          Private room in apartment
# 128463  41.37155    2.13664          Private room in apartment
# 130970 -33.89338  151.20406          Private room in townhouse
# 140197  45.43919   12.33397                   Entire apartment
# 142085  45.44018   12.33788                   Entire apartment
# 153376  41.38792    2.17768          Private room in apartment
#
#               room_type  ...  \
# id                       ...
# 35390      Private room  ...
# 47383        Hotel room  ...
# 47549   Entire home/apt  ...
# 49656   Entire home/apt  ...
# 60304      Private room  ...
# 61714      Private room  ...
# 63267   Entire home/apt  ...
# 67112      Private room  ...
# 68999      Private room  ...
# 69956   Entire home/apt  ...
# 72436   Entire home/apt  ...
# 72740   Entire home/apt  ...
# 74042   Entire home/apt  ...
# 77188   Entire home/apt  ...
# 79624      Private room  ...
# 81631   Entire home/apt  ...
# 87709      Private room  ...
# 89776   Entire home/apt  ...
# 108271     Private room  ...
# 119546     Private room  ...
# 128463     Private room  ...
# 130970     Private room  ...
# 140197  Entire home/apt  ...
# 142085  Entire home/apt  ...
# 153376     Private room  ...
#
#                                                 amenities price  \
# id
# 35390   ["Kitchen", "Microwave", "Lock on bedroom door...  12.0
# 47383   ["Shampoo", "Host greets you", "Breakfast", "E...  50.0
# 47549   ["Wifi", "First aid kit", "Dedicated workspace...  76.0
# 49656   ["Oven", "Microwave", "Hair dryer", "Iron", "D...  83.0
# 60304   ["Luggage dropoff allowed", "Long term stays a...  90.0
# 61714   ["Hair dryer", "Shampoo", "Iron", "Dedicated w...  73.0
# 63267   ["Shampoo", "Host greets you", "Breakfast", "E...  90.0
# 67112   ["Smoke alarm", "Fire extinguisher", "TV", "He...  75.0
# 68999   ["Cooking basics", "Free parking on premises",...  89.0
# 69956   ["Cooking basics", "Cleaning before checkout",...  99.0
# 72436   ["Elevator", "Kitchen", "Microwave", "Coffee m...  80.0
# 72740   ["Shampoo", "Dishwasher", "Host greets you", "...  64.0
# 74042   ["Oven", "Shampoo", "Dryer", "Host greets you"...  69.0
# 77188   ["Oven", "Shampoo", "Dishwasher", "Essentials"...  55.0
# 79624   ["Hot water", "Dishes and silverware", "Smoke ...  75.0
# 81631   ["Elevator", "Washer", "Wifi", "Air conditioni...  75.0
# 87709   ["Kitchen", "Dryer", "Washer", "Free parking o...  70.0
# 89776   ["Elevator", "Kitchen", "Hair dryer", "Air con...  85.0
# 108271  ["Shampoo", "Host greets you", "Essentials", "...  36.0
# 119546  ["Elevator", "Coffee maker", "Hot water", "Ded...  52.0
# 128463  ["Kitchen", "Microwave", "Long term stays allo...  50.0
# 130970  ["Cooking basics", "Cable TV", "Luggage dropof...  62.0
# 140197  ["Oven", "Shampoo", "Dryer", "Host greets you"...  73.0
# 142085  ["Oven", "Shampoo", "Essentials", "Lockbox", "...  40.0
# 153376  ["Refrigerator", "Hot water", "Paid parking of...  65.0
#
#         has_availability number_of_reviews  review_scores_rating  \
# id
# 35390                  t               282                  96.0
# 47383                  t               274                  98.0
# 47549                  t               145                  96.0
# 49656                  t                74                  96.0
# 60304                  t               148                  98.0
# 61714                  t               280                  98.0
# 63267                  t                11                 100.0
# 67112                  t                23                  96.0
# 68999                  t                46                  99.0
# 69956                  t                42                  97.0
# 72436                  t               354                  96.0
# 72740                  t               313                  96.0
# 74042                  t               519                  96.0
# 77188                  t               268                  98.0
# 79624                  t                93                  99.0
# 81631                  t                12                 100.0
# 87709                  t                30                  99.0
# 89776                  t               336                  96.0
# 108271                 t               326                  97.0
# 119546                 t               316                  97.0
# 128463                 t               282                  97.0
# 130970                 t               341                  97.0
# 140197                 t               659                  97.0
# 142085                 t               333                  97.0
# 153376                 t                 7                 100.0
#
#         review_scores_accuracy  review_scores_value  instant_bookable  \
# id
# 35390                     10.0                 10.0                 t
# 47383                     10.0                 10.0                 t
# 47549                     10.0                 10.0                 t
# 49656                     10.0                 10.0                 t
# 60304                     10.0                 10.0                 f
# 61714                     10.0                 10.0                 f
# 63267                     10.0                 10.0                 f
# 67112                     10.0                 10.0                 f
# 68999                     10.0                 10.0                 f
# 69956                     10.0                 10.0                 t
# 72436                      9.0                  9.0                 t
# 72740                     10.0                 10.0                 t
# 74042                     10.0                 10.0                 t
# 77188                     10.0                 10.0                 t
# 79624                     10.0                 10.0                 t
# 81631                     10.0                 10.0                 f
# 87709                     10.0                 10.0                 f
# 89776                     10.0                 10.0                 t
# 108271                    10.0                 10.0                 t
# 119546                    10.0                 10.0                 f
# 128463                    10.0                 10.0                 f
# 130970                    10.0                 10.0                 f
# 140197                    10.0                 10.0                 t
# 142085                    10.0                 10.0                 t
# 153376                    10.0                 10.0                 t
#
#        reviews_per_month  covid
# id
# 35390               2.69   9194
# 47383               2.20   2803
# 47549               1.31   2803
# 49656               0.75   2803
# 60304               1.29   2803
# 61714              14.14   2803
# 63267               0.35   2803
# 67112               0.19   5079
# 68999               0.40   5079
# 69956               0.35   5079
# 72436               4.59   9194
# 72740               2.68   2803
# 74042               4.49   2803
# 77188               2.35   2803
# 79624               0.78   5079
# 81631               0.10   9194
# 87709               0.89   5079
# 89776               3.03   9194
# 108271              3.12   2803
# 119546              2.71   9194
# 128463              2.49   9194
# 130970              3.48   5079
# 140197              5.73   2803
# 142085              2.92   2803
# 153376              0.37   9194
#
# [25 rows x 21 columns]

# %%
cheap_good.to_excel('..cleaned/good_cheap_airbb.xlsx')
